# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalC02/Machine-Learning/blob/main/JSON_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Working with **JSON**

# %%
import pandas as pd

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
df=pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')

# %%
df.head()
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  INR 2024-07-06
# AFN  https://www.exchangerate-api.com/terms  INR 2024-07-06
# ALL  https://www.exchangerate-api.com/terms  INR 2024-07-06
# AMD  https://www.exchangerate-api.com/terms  INR 2024-07-06
# ANG  https://www.exchangerate-api.com/terms  INR 2024-07-06
#
#      time_last_updated   rates
# AED         1720224001  0.0440
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162 entries, AED to ZWL
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   provider               162 non-null    object
#  1   WARNING_UPGRADE_TO_V6  162 non-null    object
#  2   terms                  162 non-null    object
#  3   base                   162 non-null    object
#  4   date                   162 non-null    datetime64[ns]
#  5   time_last_updated      162 non-null    int64
#  6   rates                  162 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 14.2+ KB

# %%
df.describe()
# Out:
#                       date  time_last_updated        rates
# count                  162       1.620000e+02   162.000000
# mean   2024-07-06 00:00:00       1.720224e+09    23.109043
# min    2024-07-06 00:00:00       1.720224e+09     0.003670
# 25%    2024-07-06 00:00:00       1.720224e+09     0.042325
# 50%    2024-07-06 00:00:00       1.720224e+09     0.283000
# 75%    2024-07-06 00:00:00       1.720224e+09     2.457500
# max    2024-07-06 00:00:00       1.720224e+09  1071.790000
# std                    NaN       0.000000e+00   102.121980

# %%
df['rates']
# Out:
# AED    0.0440
# AFN    0.8510
# ALL    1.1100
# AMD    4.6500
# ANG    0.0214
#         ...
# XPF    1.3200
# YER    3.0000
# ZAR    0.2180
# ZMW    0.2920
# ZWL    0.1640
# Name: rates, Length: 162, dtype: float64
